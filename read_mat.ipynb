# %%
import scipy.io
mat = scipy.io.loadmat('data/Pat1Train/Pat1Train_1_1.mat')

# %%
data = mat['data']
data
# Out:
# array([[ 19.369873 ,  -1.5776367, -41.794434 , ...,  62.809326 ,
#          46.628662 , -18.094238 ],
#        [ 23.331055 ,  -4.599121 , -36.759033 , ...,  70.79883  ,
#          48.575684 , -17.087158 ],
#        [ 25.345215 , -10.574463 , -34.744873 , ...,  84.831055 ,
#          52.604004 , -17.087158 ],
#        ...,
#        [-15.610107 , -36.624756 ,  21.182617 , ..., -25.07666  ,
#         -11.312988 ,  30.85083  ],
#        [-24.60669  , -28.63501  ,  19.168457 , ..., -28.0979   ,
#         -12.320068 ,  31.790771 ],
#        [-34.610596 , -26.62085  ,  19.168457 , ..., -31.119385 ,
#         -10.305908 ,  28.83667  ]], dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.plot(data)
plt.show()

# %%
data.shape
# Out:
# (240000, 16)

# %%
# Take one run
plt.plot(data[:,0])
plt.show()

# %%
plt.specgram(data[:,0])
plt.show()
# Out:
# C:\Users\hanna\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:7553: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
